# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/getmrinal/ML-Notebook/blob/master/cifar10_pca_template.ipynb)

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('cifar10.py','wb').write(src)
# Out:
#      <input type="file" id="files-8889abe3-f82c-4bd7-9c33-3d852d56a9d6" name="files[]" multiple disabled />
#      <output id="result-8889abe3-f82c-4bd7-9c33-3d852d56a9d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cifar10.py to cifar10 (1).py
# 7017

# %%
src = list(files.upload().values())[0]
open('download.py','wb').write(src)
# Out:
#      <input type="file" id="files-35dbf15f-2db4-4e80-a907-e36b26601e73" name="files[]" multiple disabled />
#      <output id="result-35dbf15f-2db4-4e80-a907-e36b26601e73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.py to download (2).py
# 3161

# %%
src = list(files.upload().values())[0]
open('dataset.py','wb').write(src)
# Out:
#      <input type="file" id="files-5c9e234a-4600-491e-ab86-30c4b5d92bc4" name="files[]" multiple disabled />
#      <output id="result-5c9e234a-4600-491e-ab86-30c4b5d92bc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.py to dataset.py
# 9672

# %%
src = list(files.upload().values())[0]
open('cache.py','wb').write(src)
# Out:
#      <input type="file" id="files-cde8276e-c5b2-4668-a17d-103263463580" name="files[]" multiple disabled />
#      <output id="result-cde8276e-c5b2-4668-a17d-103263463580">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cache.py to cache.py
# 4764

# %%
import cifar10
import matplotlib.pyplot as plt

# %%
cifar10.data_path = "data/CIFAR-10/"

# %%
cifar10.maybe_download_and_extract()
# Out:
# - Download progress: 100.0%
# Download finished. Extracting files.
# Done.

# %%
class_names = cifar10.load_class_names()
class_names
# Out:
# Loading data: data/CIFAR-10/cifar-10-batches-py/batches.meta
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
images_train, cls_train, labels_train = cifar10.load_training_data()
images_test, cls_test, labels_test = cifar10.load_test_data()
# Out:
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_1
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_2
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_3
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_4
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_5
# Loading data: data/CIFAR-10/cifar-10-batches-py/test_batch
