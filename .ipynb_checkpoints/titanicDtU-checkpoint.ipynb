# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv("titanictrain.csv")
#titanic_test = pd.read_csv("titanictest.csv")

# %%
titanic.drop("PassengerId", axis = 1, inplace = True)
titanic.drop("Name", axis=1, inplace = True)
titanic.drop("Ticket", axis=1, inplace = True)
titanic.drop("Cabin", axis=1, inplace = True)
titanic.drop("Embarked", axis=1, inplace = True)

# %%
column = ["Pclass", "Sex","SibSp", "Parch", "Survived"]
titanic = titanic.reindex(columns=column)

# %%
def f(s):
    if s == "male":
        return 0
    else:
        return 1
titanic["Sex"] =titanic.Sex.apply(f)       #apply rule/function f
titanic.head()
# Out:
#    Pclass  Sex  SibSp  Parch  Survived
# 0       3    0      1      0         0
# 1       1    1      1      0         1
# 2       3    1      0      0         1
# 3       1    1      1      0         1
# 4       3    0      0      0         0

# %% [markdown]
# Cleaned the Data and removed all the continious column from it
# The data used here is titanic dataset

# %%
X = titanic 
X = X.values #converting X into np array

# %% [markdown]
# set the column array for us as the last column is Survived which is output and hence we dont count it in features

# %%
column = ["Pclass", "Sex","SibSp", "Parch"]

# %%
def gainRatio(X,column,index):
    y = [X[X[:,index]==k] for k in np.unique(X[:,index])] #split the data based on best filt index/features
    y=np.asarray(y)                                       #saved the multidimensional array as nparray
    n,c = np.unique(X[:,4],return_counts=True)            #for entropy of parent node
    eParent = calcEntro(n,c)
    infoCh =0
    splitInfo=0
    for i in range(y.shape[0]):
        n1 ,c1 = np.unique(y[i][:,4],return_counts=True)   
        temp = calcEntro(n1,c1)                            #entropy of each child node
        xxx = (np.sum(c1)/np.sum(c))
        infoCh = infoCh + (xxx*temp)                    #infoReq for child node
        splitInfo = splitInfo + (-1*xxx)*np.log2(xxx)    #split info for child node 
    iG = eParent - infoCh                               #information gain infoParent - infoChild
   # print("eparent",eParent,"infoG",infoG)
    if(splitInfo == 0):                                 #division by 0 check
    #    print(iG," ",splitInfo)
        return 0 
    gainRatio = (iG/splitInfo)                           #calc Gain Ratio
    return gainRatio

# %%
def findBestFit(X,column):
    maxx=-99
    f = -1
    for i in range(len(column)):        #iterate over all the rest columns for best feature
        t = gainRatio(X,column,i)
        if(maxx < t):
          #  print(" ")
            maxx = t
            f = i
    return f, maxx

# %%
def calcEntro(n,c):
    totalSum = np.sum(c)
    ans =0
    for i in range(len(n)):
        m = c[i]/totalSum
        ans = ans + (-1*m)*(np.log2(m))         #entropy formula
    return ans

# %%
def printInfo(X,column,level,entropy=0,gainRatio=0,x="NA"):
    if(x=="NA"):
        print("Level",level)
        n,c = np.unique(X[:,4],return_counts=True)
     #   print(len(n))
        for i in range(len(n)):
                print("Count of",n[i],c[i])
        print("Entropy",entropy)
        print("Reached leaf Node")
    else:
        print("Level",level)
        n,c = np.unique(X[:,4],return_counts=True)
    # print(len(n))
        for i in range(len(n)):
                print("Count of",n[i],c[i])
        print("Entropy",entropy)
        print("splitting Feature based on",x," with gain ratio",gainRatio)

# %%
def decisionTree(X,column,level=0):
    if(len(np.unique(X[:,4]))==1):    #base case if node is pure 
        printInfo(X,column,level)
        print(" ")
        return
    if(len(column)==0):             #base case if no feature left to split
        n,c = np.unique(X[:,4],return_counts=True)
        entropy = calcEntro(n,c)
        printInfo(X,column,level,entropy)
        print(" ")
        return
    index,gainRatio= findBestFit(X,column)   #find the best fit feature and its gainRatio
    n,c = np.unique(X[:,4],return_counts=True)
    entropy = calcEntro(n,c)                        
    name = column[index]
    printInfo(X,column,level,entropy,gainRatio,name)
    print(" ")
    level += 1                      #inc the level
    y = [X[X[:,index]==k] for k in np.unique(X[:,index])]     #split the data on basis of feature
    y1=np.asarray(y)
    cname = column[index]
    csize = len(column)
    del column[index]
    
    for i in range(y1.shape[0]):
        #y1 = np.delete(y1[i], np.s_[index:index+1], axis=1)
        decisionTree(y1[i],column,level)
        if(len(column) < csize):
            column.append(cname)
    return

# %%
column = ["Pclass", "Sex","SibSp", "Parch"]
decisionTree(X,column,0)
# Out:
# Level 0
# Count of 0 549
# Count of 1 342
# Entropy 0.9607079018756469
# splitting Feature based on Sex  with gain ratio 0.23249201788302346
#
# Level 1
# Count of 0 468
# Count of 1 109
# Entropy 0.6991817891208407
# splitting Feature based on Pclass  with gain ratio 0.026829721319769115
#
# Level 2
# Count of 0 77
# Count of 1 45
# Entropy 0.9497869033961421
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 3
# Count of 0 77
# Count of 1 45
# Entropy 0.9497869033961421
# splitting Feature based on Parch  with gain ratio 0
#
# Level 4
# Count of 0 77
# Count of 1 45
# Entropy 0.9497869033961421
# Reached leaf Node
#
# Level 2
# Count of 0 91
# Count of 1 17
# Entropy 0.6280710155029396
# splitting Feature based on Pclass  with gain ratio 0.017829416471141307
#
# Level 3
# Count of 0 67
# Count of 1 9
# Entropy 0.524805134842907
# splitting Feature based on Parch  with gain ratio 0
#
# Level 4
# Count of 0 67
# Count of 1 9
# Entropy 0.524805134842907
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 67
# Count of 1 9
# Entropy 0.524805134842907
# Reached leaf Node
#
# Level 3
# Count of 0 20
# Count of 1 7
# Entropy 0.8256265261578954
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 4
# Count of 0 20
# Count of 1 7
# Entropy 0.8256265261578954
# splitting Feature based on Parch  with gain ratio 0
#
# Level 5
# Count of 0 20
# Count of 1 7
# Entropy 0.8256265261578954
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 6
# Count of 0 20
# Count of 1 7
# Entropy 0.8256265261578954
# Reached leaf Node
#
# Level 3
# Count of 0 4
# Count of 1 1
# Entropy 0.7219280948873623
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 4
# Count of 0 4
# Count of 1 1
# Entropy 0.7219280948873623
# splitting Feature based on Parch  with gain ratio 0
#
# Level 5
# Count of 0 4
# Count of 1 1
# Entropy 0.7219280948873623
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 6
# Count of 0 4
# Count of 1 1
# Entropy 0.7219280948873623
# Reached leaf Node
#
# Level 2
# Count of 0 300
# Count of 1 47
# Entropy 0.5721887310289433
# splitting Feature based on Pclass  with gain ratio 0.011266513778386517
#
# Level 3
# Count of 0 235
# Count of 1 35
# Entropy 0.5564215672884281
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 4
# Count of 0 235
# Count of 1 35
# Entropy 0.5564215672884281
# splitting Feature based on Parch  with gain ratio 0
#
# Level 5
# Count of 0 235
# Count of 1 35
# Entropy 0.5564215672884281
# Reached leaf Node
#
# Level 3
# Count of 0 35
# Count of 1 10
# Entropy 0.7642045065086203
# splitting Feature based on Parch  with gain ratio 0
#
# Level 4
# Count of 0 35
# Count of 1 10
# Entropy 0.7642045065086203
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 35
# Count of 1 10
# Entropy 0.7642045065086203
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 6
# Count of 0 35
# Count of 1 10
# Entropy 0.7642045065086203
# Reached leaf Node
#
# Level 3
# Count of 0 7
# Count of 1 1
# Entropy 0.5435644431995964
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 4
# Count of 0 7
# Count of 1 1
# Entropy 0.5435644431995964
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 7
# Count of 1 1
# Entropy 0.5435644431995964
# splitting Feature based on Parch  with gain ratio 0
#
# Level 6
# Count of 0 7
# Count of 1 1
# Entropy 0.5435644431995964
# Reached leaf Node
#
# Level 3
# Count of 0 4
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 11
# Count of 1 1
# Entropy 0.41381685030363374
# splitting Feature based on Parch  with gain ratio 0
#
# Level 4
# Count of 0 11
# Count of 1 1
# Entropy 0.41381685030363374
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 11
# Count of 1 1
# Entropy 0.41381685030363374
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 6
# Count of 0 11
# Count of 1 1
# Entropy 0.41381685030363374
# Reached leaf Node
#
# Level 3
# Count of 0 4
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 4
# Entropy 0
# Reached leaf Node
#
# Level 1
# Count of 0 81
# Count of 1 233
# Entropy 0.8236550739295191
# splitting Feature based on Pclass  with gain ratio 0.135485323167635
#
# Level 2
# Count of 0 3
# Count of 1 91
# Entropy 0.20390587550482003
# splitting Feature based on Sex  with gain ratio 0.005509141767776749
#
# Level 3
# Count of 0 1
# Count of 1 48
# Entropy 0.14372616993938178
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 4
# Count of 0 1
# Count of 1 48
# Entropy 0.14372616993938178
# splitting Feature based on Parch  with gain ratio 0
#
# Level 5
# Count of 0 1
# Count of 1 48
# Entropy 0.14372616993938178
# Reached leaf Node
#
# Level 3
# Count of 0 2
# Count of 1 38
# Entropy 0.28639695711595625
# splitting Feature based on Parch  with gain ratio 0
#
# Level 4
# Count of 0 2
# Count of 1 38
# Entropy 0.28639695711595625
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 2
# Count of 1 38
# Entropy 0.28639695711595625
# splitting Feature based on Sex  with gain ratio 0
#
# Level 6
# Count of 0 2
# Count of 1 38
# Entropy 0.28639695711595625
# Reached leaf Node
#
# Level 3
# Count of 1 3
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 1 2
# Entropy 0
# Reached leaf Node
#
# Level 2
# Count of 0 6
# Count of 1 70
# Entropy 0.3984592740952356
# splitting Feature based on Pclass  with gain ratio 0.018335332837718075
#
# Level 3
# Count of 0 5
# Count of 1 40
# Entropy 0.5032583347756457
# splitting Feature based on Parch  with gain ratio 0.010941971348669057
#
# Level 4
# Count of 0 3
# Count of 1 29
# Entropy 0.4488644887230294
# splitting Feature based on Sex  with gain ratio 0
#
# Level 5
# Count of 0 3
# Count of 1 29
# Entropy 0.4488644887230294
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 6
# Count of 0 3
# Count of 1 29
# Entropy 0.4488644887230294
# Reached leaf Node
#
# Level 4
# Count of 0 2
# Count of 1 10
# Entropy 0.6500224216483541
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 2
# Count of 1 10
# Entropy 0.6500224216483541
# splitting Feature based on Sex  with gain ratio 0
#
# Level 6
# Count of 0 2
# Count of 1 10
# Entropy 0.6500224216483541
# splitting Feature based on Parch  with gain ratio 0
#
# Level 7
# Count of 0 2
# Count of 1 10
# Entropy 0.6500224216483541
# Reached leaf Node
#
# Level 4
# Count of 1 1
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 1
# Count of 1 17
# Entropy 0.3095434291503252
# splitting Feature based on SibSp  with gain ratio 0.041903022461715025
#
# Level 4
# Count of 1 7
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 1
# Count of 1 8
# Entropy 0.5032583347756457
# splitting Feature based on Parch  with gain ratio 0
#
# Level 5
# Count of 0 1
# Count of 1 8
# Entropy 0.5032583347756457
# splitting Feature based on Sex  with gain ratio 0
#
# Level 6
# Count of 0 1
# Count of 1 8
# Entropy 0.5032583347756457
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 7
# Count of 0 1
# Count of 1 8
# Entropy 0.5032583347756457
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 8
# Count of 0 1
# Count of 1 8
# Entropy 0.5032583347756457
# Reached leaf Node
#
# Level 4
# Count of 1 2
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 1 11
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 1 2
# Entropy 0
# Reached leaf Node
#
# Level 2
# Count of 0 72
# Count of 1 72
# Entropy 1.0
# splitting Feature based on Sex  with gain ratio 0.04133252477628509
#
# Level 3
# Count of 0 33
# Count of 1 48
# Entropy 0.9751190649408661
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 4
# Count of 0 33
# Count of 1 48
# Entropy 0.9751190649408661
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 5
# Count of 0 33
# Count of 1 48
# Entropy 0.9751190649408661
# splitting Feature based on Parch  with gain ratio 0
#
# Level 6
# Count of 0 33
# Count of 1 48
# Entropy 0.9751190649408661
# Reached leaf Node
#
# Level 3
# Count of 0 21
# Count of 1 17
# Entropy 0.9919924034538556
# splitting Feature based on Sex  with gain ratio 0.0559155915744264
#
# Level 4
# Count of 0 11
# Count of 1 11
# Entropy 1.0
# splitting Feature based on Parch  with gain ratio 0
#
# Level 5
# Count of 0 11
# Count of 1 11
# Entropy 1.0
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 6
# Count of 0 11
# Count of 1 11
# Entropy 1.0
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 7
# Count of 0 11
# Count of 1 11
# Entropy 1.0
# Reached leaf Node
#
# Level 4
# Count of 0 5
# Count of 1 5
# Entropy 1.0
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 5
# Count of 1 5
# Entropy 1.0
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 6
# Count of 0 5
# Count of 1 5
# Entropy 1.0
# splitting Feature based on Parch  with gain ratio 0
#
# Level 7
# Count of 0 5
# Count of 1 5
# Entropy 1.0
# splitting Feature based on Sex  with gain ratio 0
#
# Level 8
# Count of 0 5
# Count of 1 5
# Entropy 1.0
# Reached leaf Node
#
# Level 4
# Count of 0 1
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 1
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 1
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on Sex  with gain ratio 0
#
# Level 5
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on Parch  with gain ratio 0
#
# Level 6
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 7
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 8
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# Reached leaf Node
#
# Level 4
# Count of 0 1
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 3
# Count of 1 4
# Entropy 0.9852281360342515
# splitting Feature based on Sex  with gain ratio 0.4493693740992486
#
# Level 4
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 5
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 6
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# splitting Feature based on Parch  with gain ratio 0
#
# Level 7
# Count of 0 1
# Count of 1 1
# Entropy 1.0
# Reached leaf Node
#
# Level 4
# Count of 1 3
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 2
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 7
# Count of 1 1
# Entropy 0.5435644431995964
# splitting Feature based on Sex  with gain ratio 0.4185144445577853
#
# Level 4
# Count of 1 1
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 5
# Entropy 0
# Reached leaf Node
#
# Level 4
# Count of 0 2
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 4
# Count of 1 2
# Entropy 0.9182958340544896
# splitting Feature based on Parch  with gain ratio 0
#
# Level 4
# Count of 0 4
# Count of 1 2
# Entropy 0.9182958340544896
# splitting Feature based on Pclass  with gain ratio 0
#
# Level 5
# Count of 0 4
# Count of 1 2
# Entropy 0.9182958340544896
# splitting Feature based on SibSp  with gain ratio 0
#
# Level 6
# Count of 0 4
# Count of 1 2
# Entropy 0.9182958340544896
# splitting Feature based on Sex  with gain ratio 0
#
# Level 7
# Count of 0 4
# Count of 1 2
# Entropy 0.9182958340544896
# Reached leaf Node
#
# Level 3
# Count of 0 1
# Entropy 0
# Reached leaf Node
#
# Level 3
# Count of 0 3
# Entropy 0
# Reached leaf Node

# %%
column
# Out:
# ['Sex', 'SibSp', 'Pclass', 'Parch']

# %% [markdown]
# ## Changes Made

# %%
#best fit mai return f, maxx
#column delete krne ke baad waapis append bhi krna tha in decisiontreefunction because wrna woh further uske basis pr kabhi split nhi kr paayega for the different levels
