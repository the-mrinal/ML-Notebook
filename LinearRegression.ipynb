# %%
import numpy as np
import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression

# %%
data =np.genfromtxt("titanictest.csv",delimiter =",")
df = pd.DataFrame(df)
df.columns = ["Data","output"]
X = df.Data
Y = df.output
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X,Y,test_size=0.3)
X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-61a00a2ca17d> in <module>()
# ----> 1 data =np.genfromtxt("titanictest.csv",delimiter =",")
#       2 df = pd.DataFrame(df)
#       3 df.columns = ["Data","output"]
#       4 X = df.Data
#       5 Y = df.output
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2012             # Raise an exception ?
#    2013             if invalid_raise:
# -> 2014                 raise ValueError(errmsg)
#    2015             # Issue a warning ?
#    2016             else:
#
# ValueError: Some errors were detected !
# ...

# %%
def fit(X,Y):
    a = (X*Y).mean() - X.mean()*Y.mean()
    b = (X*X).mean() - X.mean()*X.mean()
    m = a/b
    c = Y.mean() - m*X.mean()
    return (m,c)

# %%
def predict(X,m,c):
    Y_p = m*X + c
    return Y_p

# %%
def coeffOfDet(Y_p,Y):
    u = np.sum((Y - Y_p)**2)
    v = np.sum((Y-Y.mean())**2)
    score = 1-(u/v)
    return score

# %%
def cost(X,Y,m,c):
    cot = np.mean((Y-(m*X+c))**2)
    return cot

# %%
m,c = fit(X_train,Y_train)
Y_p = predict(X_train,m,c)
score = coeffOfDet(Y_p,Y_train)
cot = cost(X,Y,m,c)
m,c,score,cot
# Out:
# (1.2775549968922102,
#  11.071795667338847,
#  0.5474639732781446,
#  111.22772972446126)

# %%
algo = LinearRegression()
algo.fit(X_train,Y_train)
Y_pred = algo.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-146c3f404c25> in <module>()
#       1 algo = LinearRegression()
# ----> 2 algo.fit(X_train,Y_train)
#       3 Y_pred = algo.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...
