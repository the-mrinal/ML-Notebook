# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4]
y = [4,5,6,7]
plt.scatter(x,y)
x1=[33,44,55,66]
y1=[77,88,99,0]
plt.plot(x1,y1,"r-.")
plt.show()

# %%
#plot x^3
x = np.arange(0,700,0.1)
y = np.power(x,3)
y1 =np.power(x,2)
plt.plot(x,y,"r-.")
plt.plot(x,y1,"b-.")

plt.show()
